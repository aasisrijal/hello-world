# %% [markdown]
# <a href="https://colab.research.google.com/github/aasisrijal/hello-world/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
train_dir='/content/gdrive/My Drive/Colab Notebooks/fakeNote/new/train'
validaton_dir='/content/gdrive/My Drive/Colab Notebooks/fakeNote/new/valid'

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline

# %%
import math
import itertools
from sklearn.metrics import classification_report, confusion_matrix

# %%
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
batch_size = 100
epochs = 100
IMG_SHAPE = 224

# %%
#setting data generators
from keras.preprocessing.image import  ImageDataGenerator

train_datagen = ImageDataGenerator(
                    rescale=1./255, 
                    rotation_range=45, 
                    width_shift_range=.15, 
                    height_shift_range=.15, 
                    horizontal_flip=True, 
                    zoom_range=0.5)
valid_datagen = ImageDataGenerator(rescale=1./255)
# Out:
# Using TensorFlow backend.

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    batch_size = batch_size,
    shuffle = True,
    class_mode='binary',
    target_size=(IMG_SHAPE,IMG_SHAPE))

validation_generator = valid_datagen.flow_from_directory(
    validaton_dir,
    batch_size = 50,
    target_size=(IMG_SHAPE,IMG_SHAPE),
    class_mode='binary')
# Out:
# Found 3544 images belonging to 2 classes.
# Found 1004 images belonging to 2 classes.

# %%
sample_training_images, _ = next(train_generator)

# %%
plotImages(sample_training_images[:5])

# %%
for data_batch, labels_batch in train_generator:
  print('data bench shape:', data_batch.shape)
  print('labels batch shape', labels_batch.shape)
  break
# Out:
# data bench shape: (100, 224, 224, 3)
# labels batch shape (100,)

# %% [markdown]
# Building the model

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, Lambda, MaxPooling2D

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))
# Out:
# W0715 06:02:15.922107 140012303845248 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0715 06:02:15.941071 140012303845248 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0715 06:02:15.993504 140012303845248 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0715 06:02:16.016955 140012303845248 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# ...

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 26, 26, 128)       0
# ...

# %%
model.compile(
    optimizer=tf.train.AdamOptimizer(learning_rate=0.0001),
    loss='binary_crossentropy',
    metrics=['binary_accuracy'])
# Out:
# W0715 06:02:41.016348 140012303845248 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0715 06:02:41.039634 140012303845248 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0715 06:02:41.048445 140012303845248 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
history = model.fit_generator(train_generator,
                                   validation_data=validation_generator,
                                   epochs=25,
                                   steps_per_epoch=20,
                                   validation_steps=20)
# Out:
# Epoch 1/25
# 20/20 [==============================] - 869s 43s/step - loss: 0.6807 - binary_accuracy: 0.5700 - val_loss: 0.6872 - val_binary_accuracy: 0.5000
# Epoch 2/25
# 20/20 [==============================] - 443s 22s/step - loss: 0.6726 - binary_accuracy: 0.5719 - val_loss: 0.6797 - val_binary_accuracy: 0.4990
# Epoch 3/25
# 20/20 [==============================] - 280s 14s/step - loss: 0.6594 - binary_accuracy: 0.5870 - val_loss: 0.6475 - val_binary_accuracy: 0.6216
# Epoch 4/25
# 20/20 [==============================] - 276s 14s/step - loss: 0.6473 - binary_accuracy: 0.6110 - val_loss: 0.6196 - val_binary_accuracy: 0.6698
# Epoch 5/25
# 20/20 [==============================] - 284s 14s/step - loss: 0.6148 - binary_accuracy: 0.6555 - val_loss: 0.5559 - val_binary_accuracy: 0.7642
# Epoch 6/25
# 20/20 [==============================] - 279s 14s/step - loss: 0.5576 - binary_accuracy: 0.6959 - val_loss: 0.4879 - val_binary_accuracy: 0.8145
# Epoch 7/25
# ...

# %%
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(25)

plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.save('fakeThousandNote.h5')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:118: UserWarning: TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
#   'TensorFlow optimizers do not '

# %%
from google.colab import files

files.download('fakeThousandNote.h5')

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
pred = model.predict_generator(validation_generator, steps = 25)

# %%
pred.shape
# Out:
# (1204, 1)

# %%
y_pred = np.argmax(pred, axis=1)

# %%
y_pred.shape
# Out:
# (454,)

# %%
print(confusion_matrix(validation_generator.classes, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-03dc3ccaa4f0> in <module>()
# ----> 1 print(confusion_matrix(validation_generator.classes, y_pred))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     254     if y_type not in ("binary", "multiclass"):
#     255         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py in _check_targets(y_true, y_pred)
#      69     y_pred : array or indicator matrix
#      70     """
# ---> 71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
#      73     type_pred = type_of_target(y_pred)
#
# ...
